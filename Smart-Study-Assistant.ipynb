# %%
from google import genai
from google.genai import types
import os
from dotenv import load_dotenv

load_dotenv()
client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

# %%
def study_assistant(question):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=question
    )
    return response.text

# %%
print(study_assistant("what is LLM"))
# Out:
# **LLM stands for Large Language Model.**
#
# In simple terms, an LLM is a type of artificial intelligence (AI) program that has been trained on a massive amount of text data (like books, articles, websites, conversations, etc.) to understand, generate, and manipulate human language.
#
# Here's a breakdown of what that means:
#
# 1.  **Large:**
#     *   **Data:** They are trained on truly enormous datasets – often billions or even trillions of words. This vast amount of data allows them to learn the nuances of language, grammar, facts, common sense, and various writing styles.
#     *   **Parameters:** They have billions or even trillions of "parameters" (internal variables) that the model adjusts during training. More parameters generally mean a greater capacity to learn complex patterns and generate more sophisticated responses.
#     *   **Computational Power:** Training and running these models requires immense computational resources (powerful computers and GPUs).
#
# 2.  **Language:**
#     *   Their primary function revolves around human language. They are designed to process and produce text that sounds natural and coherent.
#     *   The core task during training is often predicting the next word in a sentence, or filling in missing words. This seemingly simple task forces the model to learn context, semantics, and grammar.
#
# 3.  **Model:**
#     *   In AI, a "model" is an algorithm or system that has been trained to perform a specific task. In this case, the task is understanding and generating language.
#     *   LLMs are typically built using deep learning architectures, most famously the "Transformer" architecture, which is excellent at handling sequential data like text.
#
# **What can LLMs do? (Key Capabilities):**
#
# Because they've seen so much text, LLMs can perform a wide range of language-related tasks, including:
#
# *   **Generating Text:** Writing articles, stories, poems, emails, code, scripts, etc.
# *   **Answering Questions:** Providing factual information, explanations, or creative responses based on their training data.
# *   **Summarizing:** Condensing long documents or conversations into shorter, key points.
# *   **Translating:** Converting text from one language to another.
# *   **Rewriting/Rephrasing:** Changing the tone, style, or complexity of existing text.
# *   **Chatbot/Conversational AI:** Engaging in dynamic, human-like conversations.
# *   **Code Generation & Explanation:** Writing code in various programming languages or explaining existing code.
# *   **Reasoning (to some extent):** Inferring relationships, drawing conclusions, and solving logic puzzles based on patterns learned from text.
#
# **Examples of well-known LLMs:**
#
# *   **OpenAI's GPT series:** GPT-3, GPT-3.5, GPT-4 (used in products like ChatGPT)
# *   **Google's models:** PaLM, LaMDA, Gemini
# *   **Meta's LLaMA series**
# *   **Anthropic's Claude**
#
# **In essence, LLMs are incredibly powerful and versatile AI systems that have revolutionized how we interact with and generate text, opening up new possibilities across many industries and applications.**
